# %%
import pandas as pd
import numpy as np

# %%
initial_data = pd.read_csv('https://raw.githubusercontent.com/jlian014/yelp/master/Jane/yelp_dataset_final.csv')

# %%
initial_data.head()
# Out:
#    Index    zip  yelp_dollar_1  yelp_dollar_2  yelp_dollar_3  yelp_dollar_4  \
# 0      0  12919              1              1              1              0
# 1      1  12923              0              1              0              0
# 2      2  12979              3              1              0              0
# 3      3  15003              6              8              0              2
# 4      4  15015              0              1              0              0
#
#    Total_Business STATE  income_level_1  income_level_2  income_level_3  \
# 0               3    NY           580.0           420.0           250.0
# 1               1    NY            80.0            70.0            30.0
# 2               4    NY           430.0           290.0           160.0
# 3              16    PA          2340.0          1650.0           820.0
# 4               1    PA           160.0            70.0            60.0
#
#    income_level_4  income_level_5  income_level_6  target
# 0           170.0           160.0             0.0       2
# 1            20.0            20.0             0.0       2
# 2           130.0           160.0             0.0       2
# 3           450.0           360.0            40.0       2
# 4            70.0           190.0           110.0       4

# %%
initial_data['total_returns'] = initial_data[['income_level_1','income_level_2','income_level_3',
                                             'income_level_4', 'income_level_5','income_level_6']].sum(axis=1)

# %%
initial_data['perc_of_six'] = initial_data['income_level_6'] / initial_data['total_returns']
initial_data['perc_of_five'] = initial_data['income_level_5'] / initial_data['total_returns']
initial_data['perc_of_four'] = initial_data['income_level_4'] / initial_data['total_returns']
initial_data['perc_of_three'] = initial_data['income_level_3'] / initial_data['total_returns']
initial_data['perc_of_two'] = initial_data['income_level_2'] / initial_data['total_returns']
initial_data['perc_of_one'] = initial_data['income_level_1'] / initial_data['total_returns']

# %%
initial_data['perc_of_yelp1'] = initial_data['yelp_dollar_1'] / initial_data['Total_Business']
initial_data['perc_of_yelp2'] = initial_data['yelp_dollar_2'] / initial_data['Total_Business']
initial_data['perc_of_yelp3'] = initial_data['yelp_dollar_3'] / initial_data['Total_Business']
initial_data['perc_of_yelp4'] = initial_data['yelp_dollar_4'] / initial_data['Total_Business']

# %%
initial_data['yelp_dollar_1_weighted'] = initial_data['yelp_dollar_1'] + 5

# %%
initial_data['yelp_dollar_2_weighted'] = initial_data['yelp_dollar_2'] + 5
initial_data['yelp_dollar_3_weighted'] = initial_data['yelp_dollar_3'] + 5
initial_data['yelp_dollar_4_weighted'] = initial_data['yelp_dollar_4'] + 5

# %%
initial_data['perc_of_yelp1_weighted'] = initial_data['yelp_dollar_1_weighted'] / initial_data['Total_Business']
initial_data['perc_of_yelp2_weighted'] = initial_data['yelp_dollar_2_weighted'] / initial_data['Total_Business']
initial_data['perc_of_yelp3_weighted'] = initial_data['yelp_dollar_3_weighted'] / initial_data['Total_Business']
initial_data['perc_of_yelp4_weighted'] = initial_data['yelp_dollar_4_weighted'] / initial_data['Total_Business']

# %%
initial_data['income_level_1_weighted'] = initial_data['income_level_1'] + 5
initial_data['income_level_2_weighted'] = initial_data['income_level_2'] + 5
initial_data['income_level_3_weighted'] = initial_data['income_level_3'] + 5
initial_data['income_level_4_weighted'] = initial_data['income_level_4'] + 5
initial_data['income_level_5_weighted'] = initial_data['income_level_5'] + 5
initial_data['income_level_6_weighted'] = initial_data['income_level_6'] + 5

# %%
initial_data['weighted_returns'] = initial_data[['income_level_1_weighted','income_level_2_weighted','income_level_3_weighted',
                                             'income_level_4_weighted', 'income_level_5_weighted','income_level_6_weighted']].sum(axis=1)

# %%
initial_data['perc_of_six_weighted'] = initial_data['income_level_6_weighted'] / initial_data['weighted_returns']
initial_data['perc_of_five_weighted'] = initial_data['income_level_5_weighted'] / initial_data['weighted_returns']
initial_data['perc_of_four_weighted'] = initial_data['income_level_4_weighted'] / initial_data['weighted_returns']
initial_data['perc_of_three_weighted'] = initial_data['income_level_3_weighted'] / initial_data['weighted_returns']
initial_data['perc_of_two_weighted'] = initial_data['income_level_2_weighted'] / initial_data['weighted_returns']
initial_data['perc_of_one_weighted'] = initial_data['income_level_1_weighted'] / initial_data['weighted_returns']

# %%
initial_data['total_aff'] = (initial_data['perc_of_one_weighted']) + (initial_data['perc_of_two_weighted'] * 2) + (initial_data['perc_of_three_weighted'] * 3) + (initial_data['perc_of_four_weighted'] * 4) + (initial_data['perc_of_five_weighted'] * 5) + (initial_data['perc_of_six_weighted'] * 6)

# %%
initial_data.sort_values('total_aff',ascending=False).head()
# Out:
#      Index    zip  yelp_dollar_1  yelp_dollar_2  yelp_dollar_3  yelp_dollar_4  \
# 406    406  85262              3              7              1              0
# 143    143  28207              9             13              0              1
# 398    398  85253             44             80             16              7
# 408    408  85266             12             23              2              1
# 181    181  44040              3              2              0              0
#
#      Total_Business STATE  income_level_1  income_level_2    ...      \
# 406              11    AZ           900.0           560.0    ...
# 143              23    NC           840.0           540.0    ...
# 398             147    AZ          1690.0           940.0    ...
# 408              38    AZ          1010.0           530.0    ...
# 181               5    OH           360.0           180.0    ...
#
#      income_level_5_weighted  income_level_6_weighted  weighted_returns  \
# 406                   1345.0                   1665.0            5410.0
# 143                    545.0                   1775.0            4390.0
# 398                   1115.0                   3155.0            8110.0
# 408                   1285.0                   1355.0            5080.0
# 181                    335.0                    495.0            1710.0
#
#      perc_of_six_weighted  perc_of_five_weighted  perc_of_four_weighted  \
# 406              0.307763               0.248614               0.084104
# 143              0.404328               0.124146               0.067198
# 398              0.389026               0.137485               0.063502
# 408              0.266732               0.252953               0.085630
# 181              0.289474               0.195906               0.102339
#
#      perc_of_three_weighted  perc_of_two_weighted  perc_of_one_weighted  \
# 406                0.087800              0.104436              0.167283
# 143                0.087699              0.124146              0.192483
# 398                0.084464              0.116523              0.209001
# 408                0.089567              0.105315              0.199803
# 181                0.090643              0.108187              0.213450
#
#      total_aff
# 406   4.065619
# 143   4.019362
# 398   3.971023
# 408   3.886811
# 181   3.827485
#
# [5 rows x 48 columns]

# %%
initial_data.sort_values('perc_of_six',ascending=False).head()
# Out:
#      Index    zip  yelp_dollar_1  yelp_dollar_2  yelp_dollar_3  yelp_dollar_4  \
# 143    143  28207              9             13              0              1
# 398    398  85253             44             80             16              7
# 406    406  85262              3              7              1              0
# 181    181  44040              3              2              0              0
# 48      48  15142              0              1              0              0
#
#      Total_Business STATE  income_level_1  income_level_2    ...      \
# 143              23    NC           840.0           540.0    ...
# 398             147    AZ          1690.0           940.0    ...
# 406              11    AZ           900.0           560.0    ...
# 181               5    OH           360.0           180.0    ...
# 48                1    PA           200.0           170.0    ...
#
#      income_level_5_weighted  income_level_6_weighted  weighted_returns  \
# 143                    545.0                   1775.0            4390.0
# 398                   1115.0                   3155.0            8110.0
# 406                   1345.0                   1665.0            5410.0
# 181                    335.0                    495.0            1710.0
# 48                     195.0                    315.0            1130.0
#
#      perc_of_six_weighted  perc_of_five_weighted  perc_of_four_weighted  \
# 143              0.404328               0.124146               0.067198
# 398              0.389026               0.137485               0.063502
# 406              0.307763               0.248614               0.084104
# 181              0.289474               0.195906               0.102339
# 48               0.278761               0.172566               0.092920
#
#      perc_of_three_weighted  perc_of_two_weighted  perc_of_one_weighted  \
# 143                0.087699              0.124146              0.192483
# 398                0.084464              0.116523              0.209001
# 406                0.087800              0.104436              0.167283
# 181                0.090643              0.108187              0.213450
# 48                 0.119469              0.154867              0.181416
#
#      total_aff
# 143   4.019362
# 398   3.971023
# 406   4.065619
# 181   3.827485
# 48    3.756637
#
# [5 rows x 48 columns]

# %%
initial_data.loc[initial_data['zip'] == 15142]
# Out:
#     Index    zip  yelp_dollar_1  yelp_dollar_2  yelp_dollar_3  yelp_dollar_4  \
# 48     48  15142              0              1              0              0
#
#     Total_Business STATE  income_level_1  income_level_2    ...      \
# 48               1    PA           200.0           170.0    ...
#
#     income_level_5_weighted  income_level_6_weighted  weighted_returns  \
# 48                    195.0                    315.0            1130.0
#
#     perc_of_six_weighted  perc_of_five_weighted  perc_of_four_weighted  \
# 48              0.278761               0.172566                0.09292
#
#     perc_of_three_weighted  perc_of_two_weighted  perc_of_one_weighted  \
# 48                0.119469              0.154867              0.181416
#
#     total_aff
# 48   3.756637
#
# [1 rows x 48 columns]

# %%
initial_data.head()
# Out:
#    Index    zip  yelp_dollar_1  yelp_dollar_2  yelp_dollar_3  yelp_dollar_4  \
# 0      0  12919              1              1              1              0
# 1      1  12923              0              1              0              0
# 2      2  12979              3              1              0              0
# 3      3  15003              6              8              0              2
# 4      4  15015              0              1              0              0
#
#    Total_Business STATE  income_level_1  income_level_2      ...        \
# 0               3    NY           580.0           420.0      ...
# 1               1    NY            80.0            70.0      ...
# 2               4    NY           430.0           290.0      ...
# 3              16    PA          2340.0          1650.0      ...
# 4               1    PA           160.0            70.0      ...
#
#    perc_of_six  perc_of_one  perc_of_five  perc_of_four  perc_of_three  \
# 0     0.000000     0.367089      0.101266      0.107595       0.158228
# 1     0.000000     0.363636      0.090909      0.090909       0.136364
# 2     0.000000     0.367521      0.136752      0.111111       0.136752
# 3     0.007067     0.413428      0.063604      0.079505       0.144876
# 4     0.166667     0.242424      0.287879      0.106061       0.090909
#
#    perc_of_two  perc_of_yelp1  perc_of_yelp2  perc_of_yelp3  perc_of_yelp4
# 0     0.265823       0.333333       0.333333       0.333333          0.000
# 1     0.318182       0.000000       1.000000       0.000000          0.000
# 2     0.247863       0.750000       0.250000       0.000000          0.000
# 3     0.291519       0.375000       0.500000       0.000000          0.125
# 4     0.106061       0.000000       1.000000       0.000000          0.000
#
# [5 rows x 26 columns]

# %%
initial_data.head()
# Out:
#    Index    zip  yelp_dollar_1  yelp_dollar_2  yelp_dollar_3  yelp_dollar_4  \
# 0      0  12919              1              1              1              0
# 1      1  12923              0              1              0              0
# 2      2  12979              3              1              0              0
# 3      3  15003              6              8              0              2
# 4      4  15015              0              1              0              0
#
#    Total_Business STATE  income_level_1  income_level_2     ...       \
# 0               3    NY           580.0           420.0     ...
# 1               1    NY            80.0            70.0     ...
# 2               4    NY           430.0           290.0     ...
# 3              16    PA          2340.0          1650.0     ...
# 4               1    PA           160.0            70.0     ...
#
#    income_level_5  income_level_6  target  total_returns  perc_of_six  \
# 0           160.0             0.0       2         1580.0     0.000000
# 1            20.0             0.0       2          220.0     0.000000
# 2           160.0             0.0       2         1170.0     0.000000
# 3           360.0            40.0       2         5660.0     0.007067
# 4           190.0           110.0       4          660.0     0.166667
#
#    perc_of_one  perc_of_five  perc_of_four  perc_of_three  perc_of_two
# 0     0.367089      0.101266      0.107595       0.158228     0.265823
# 1     0.363636      0.090909      0.090909       0.136364     0.318182
# 2     0.367521      0.136752      0.111111       0.136752     0.247863
# 3     0.413428      0.063604      0.079505       0.144876     0.291519
# 4     0.242424      0.287879      0.106061       0.090909     0.106061
#
# [5 rows x 22 columns]

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
initial_data['STATE'].value_counts()
# Out:
# AZ    125
# PA    105
# OH    105
# NV     61
# NC     55
# WI     33
# IL     19
# CA      5
# SC      4
# NY      3
# OR      3
# IN      3
# TX      1
# KY      1
# CO      1
# VA      1
# Name: STATE, dtype: int64

# %%
ohio = initial_data.loc[initial_data['STATE'] == 'OH']
charlotte = initial_data.loc[initial_data['STATE'] == 'NC']
vegas = initial_data.loc[initial_data['STATE'] == 'NV']
zona = initial_data.loc[initial_data['STATE'] == 'AZ']
pitts = initial_data.loc[initial_data['STATE'] == 'PA']
madison = initial_data.loc[initial_data['STATE'] == 'WI']
illinois = initial_data.loc[initial_data['STATE'] == 'IL']

# %% [markdown]
# ## Total Dataset Heatmap

# %%
plt.figure(figsize = (7,12))
#mask = np.triu(np.ones_like(initial_data.select_dtypes(['float64', 'int64']).corr()))
sns.heatmap(initial_data.corr()[['target','perc_of_six_weighted','total_aff','perc_of_six']].sort_values('target'),
            annot=True,annot_kws={"size":11}, cmap='ocean',)

# %% [markdown]
# ### Ohio Heatmap

# %%
plt.figure(figsize = (7,12))
#mask = np.triu(np.ones_like(initial_data.select_dtypes(['float64', 'int64']).corr()))
sns.heatmap(ohio.corr()[['target','perc_of_six_weighted','total_aff','perc_of_six']].sort_values('target'),
            annot=True,annot_kws={"size":11}, cmap='ocean',)

# %% [markdown]
# ### Charlotte

# %%
plt.figure(figsize = (7,12))
#mask = np.triu(np.ones_like(initial_data.select_dtypes(['float64', 'int64']).corr()))
sns.heatmap(charlotte.corr()[['target','perc_of_six_weighted','total_aff','perc_of_six']].sort_values('target'),
            annot=True,annot_kws={"size":11}, cmap='ocean',)

# %% [markdown]
# ### Las Vegas

# %%
plt.figure(figsize = (7,12))
#mask = np.triu(np.ones_like(initial_data.select_dtypes(['float64', 'int64']).corr()))
sns.heatmap(vegas.corr()[['target','perc_of_six_weighted','total_aff','perc_of_six']].sort_values('target'),
            annot=True,annot_kws={"size":11}, cmap='ocean',)

# %% [markdown]
# ### Phoenix

# %%
plt.figure(figsize = (7,12))
#mask = np.triu(np.ones_like(initial_data.select_dtypes(['float64', 'int64']).corr()))
sns.heatmap(zona.corr()[['target','perc_of_six_weighted','total_aff','perc_of_six']].sort_values('target'),
            annot=True,annot_kws={"size":11}, cmap='ocean',)

# %% [markdown]
# ### Pittsburgh

# %%
plt.figure(figsize = (7,12))
#mask = np.triu(np.ones_like(initial_data.select_dtypes(['float64', 'int64']).corr()))
sns.heatmap(pitts.corr()[['target','perc_of_six_weighted','total_aff','perc_of_six']].sort_values('target'),
            annot=True,annot_kws={"size":11}, cmap='ocean',)

# %%
plt.figure(figsize = (7,12))
#mask = np.triu(np.ones_like(initial_data.select_dtypes(['float64', 'int64']).corr()))
sns.heatmap(madison.corr()[['target','perc_of_six_weighted','total_aff','perc_of_six']].sort_values('target'),
            annot=True,annot_kws={"size":11}, cmap='ocean',)

# %%
plt.figure(figsize = (7,12))
#mask = np.triu(np.ones_like(initial_data.select_dtypes(['float64', 'int64']).corr()))
sns.heatmap(illinois.corr()[['target','perc_of_six_weighted','total_aff','perc_of_six']].sort_values('target'),
            annot=True,annot_kws={"size":11}, cmap='ocean',)

# %%
plt.hist(initial_data['target'],bins=4)
# Out:
# (array([ 44., 328., 129.,  24.]),
#  array([1., 2., 3., 4., 5.]),
#  <a list of 4 Patch objects>)

# %%
plt.hist(ohio['target'],bins=4)
# Out:
# (array([14., 63., 25.,  3.]),
#  array([1.  , 1.75, 2.5 , 3.25, 4.  ]),
#  <a list of 4 Patch objects>)

# %%
plt.hist(pitts['target'],bins=4)
# Out:
# (array([ 6., 76., 17.,  6.]),
#  array([1.  , 1.75, 2.5 , 3.25, 4.  ]),
#  <a list of 4 Patch objects>)

# %%
plt.hist(illinois['target'],bins=2)
# Out:
# (array([13.,  6.]), array([2. , 2.5, 3. ]), <a list of 2 Patch objects>)

# %%
plt.hist(vegas['target'],bins=4)
# Out:
# (array([ 9., 38., 13.,  1.]),
#  array([1.  , 1.75, 2.5 , 3.25, 4.  ]),
#  <a list of 4 Patch objects>)

# %%
plt.hist(zona['target'],bins=4)
# Out:
# (array([10., 76., 27., 12.]),
#  array([1., 2., 3., 4., 5.]),
#  <a list of 4 Patch objects>)

# %%
plt.hist(charlotte['target'],bins=4)
# Out:
# (array([ 4., 32., 17.,  2.]),
#  array([1., 2., 3., 4., 5.]),
#  <a list of 4 Patch objects>)

# %%
plt.hist(ohio['target'],bins=4)
# Out:
# (array([14., 63., 25.,  3.]),
#  array([1.  , 1.75, 2.5 , 3.25, 4.  ]),
#  <a list of 4 Patch objects>)

# %%
over_40 = initial_data.loc[initial_data['Total_Business'] > 20]

# %%
plt.hist(over_40['target'],bins=4)
# Out:
# (array([ 29., 209.,  86.,  16.]),
#  array([1., 2., 3., 4., 5.]),
#  <a list of 4 Patch objects>)

# %%
plt.figure(figsize = (7,12))
#mask = np.triu(np.ones_like(initial_data.select_dtypes(['float64', 'int64']).corr()))
sns.heatmap(over_40.corr()[['target','perc_of_six_weighted','total_aff','perc_of_six']].sort_values('target'),
            annot=True,annot_kws={"size":11}, cmap='ocean',)

# %%
plt.hist(initial_data['Total_Business'],bins=5);

# %%
plt.hist(ohio['Total_Business'],bins=5);

# %% [markdown]
# ### Total Dataset

# %%
plt.hist(initial_data['total_returns'],bins=5);

# %%
plt.hist(initial_data['perc_of_six'],bins=5);

# %%
plt.hist(initial_data['target'],bins=5);

# %% [markdown]
# ### Ohio

# %%
plt.hist(ohio['total_returns'],bins=5);

# %% [markdown]
# ## Pittsburgh

# %%
plt.hist(pitts['total_returns'],bins=5);

# %% [markdown]
# # Arizona

# %%
plt.hist(zona['total_returns'],bins=5);

# %%
plt.hist(vegas['total_returns'],bins=5);

# %% [markdown]
# ### Madison

# %%
plt.hist(madison['total_returns'],bins=5);

# %% [markdown]
# ### Illinois

# %%
plt.hist(illinois['total_returns'],bins=5);

# %%
zip_stats = pd.read_csv('/Volumes/data/IRS_zipcodes_clean.csv')

# %%
zip_stats.head()
# Out:
#    zipcode        1       2       3       4       5       6
# 0    10001   3740.0  2500.0  1950.0  1410.0  2580.0  2340.0
# 1    10002  21180.0  8210.0  4810.0  2710.0  3620.0  1650.0
# 2    10003   5030.0  3870.0  3960.0  3220.0  6300.0  6280.0
# 3    10004    360.0   250.0   290.0   210.0   520.0   850.0
# 4    10005    690.0   750.0   860.0   660.0  1360.0  1620.0

# %%
zip_stats['total'] = zip_stats[['1','2','3','4','5','6']].sum(axis=1)

# %%
zip_stats['perc_of_six'] = zip_stats['6'] / zip_stats['total']

# %%
plt.hist(zip_stats['perc_of_six'])
# Out:
# (array([2.4344e+04, 1.9140e+03, 6.7800e+02, 2.9900e+02, 1.7000e+02,
#         6.9000e+01, 5.2000e+01, 1.8000e+01, 1.0000e+00, 3.0000e+00]),
#  array([0.  , 0.06, 0.12, 0.18, 0.24, 0.3 , 0.36, 0.42, 0.48, 0.54, 0.6 ]),
#  <a list of 10 Patch objects>)

# %%
zip_stats['income_level_1_weighted'] = zip_stats['1'] + 5
zip_stats['income_level_2_weighted'] = zip_stats['2'] + 5
zip_stats['income_level_3_weighted'] = zip_stats['3'] + 5
zip_stats['income_level_4_weighted'] = zip_stats['4'] + 5
zip_stats['income_level_5_weighted'] = zip_stats['5'] + 5
zip_stats['income_level_6_weighted'] = zip_stats['6'] + 5

# %%
zip_stats['weighted_returns'] = zip_stats[['income_level_1_weighted','income_level_2_weighted','income_level_3_weighted',
                                             'income_level_4_weighted', 'income_level_5_weighted','income_level_6_weighted']].sum(axis=1)

# %%
zip_stats['perc_of_six_weighted'] = zip_stats['income_level_6_weighted'] / zip_stats['weighted_returns']
zip_stats['perc_of_five_weighted'] = zip_stats['income_level_5_weighted'] / zip_stats['weighted_returns']
zip_stats['perc_of_four_weighted'] = zip_stats['income_level_4_weighted'] / zip_stats['weighted_returns']
zip_stats['perc_of_three_weighted'] = zip_stats['income_level_3_weighted'] / zip_stats['weighted_returns']
zip_stats['perc_of_two_weighted'] = zip_stats['income_level_2_weighted'] / zip_stats['weighted_returns']
zip_stats['perc_of_one_weighted'] = zip_stats['income_level_1_weighted'] / zip_stats['weighted_returns']

# %%
zip_stats['total_aff'] = (zip_stats['perc_of_one_weighted']) + (zip_stats['perc_of_two_weighted'] * 2)  + (zip_stats['perc_of_three_weighted'] * 3) + (zip_stats['perc_of_four_weighted'] * 4) + (zip_stats['perc_of_five_weighted'] * 5) + (zip_stats['perc_of_six_weighted'] * 6)

# %%
plt.hist(zip_stats['total_aff']);
